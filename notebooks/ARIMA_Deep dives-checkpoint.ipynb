# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pmdarima as pm

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from matplotlib.pyplot import figure
from statsmodels.tsa.arima.model import ARIMA  #statsmodels 0.12+

# %%
import statsmodels as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# # Data extract

# %%
df_init = pd.read_csv('/home/dellih/code/greengamma/long-short-trade-ideas-generator/notebooks/cleaned_data_test.csv', index_col=0)

# %%
df_init
# Out:
#              TEL_BIO   ADP_SYK     ON_MU  ROST_VFC      CDW_T  PAYX_RTX  \
# Date
# 2022-02-23  0.239509  0.771140  0.663637  1.560298   9.729875  1.237427
# 2022-02-24  0.234301  0.774126  0.689893  1.592246  10.004847  1.227451
# 2022-02-25  0.223696  0.766083  0.707117  1.601182  10.073827  1.208059
# 2022-02-28  0.225564  0.773484  0.706936  1.594907   9.877013  1.158270
# 2022-03-01  0.217456  0.767553  0.693815  1.633461   9.768311  1.143246
# ...              ...       ...       ...       ...        ...       ...
# 2022-08-17  0.258362  1.177302  1.108244  1.969446   9.914223  1.467810
# 2022-08-18  0.263737  1.181579  1.163068  1.972979  10.152469  1.469327
# 2022-08-19  0.264347  1.191070  1.198645  1.998024  10.220835  1.482762
# 2022-08-22  0.259488  1.207346  1.179901  2.042420  10.210149  1.481151
# 2022-08-23  0.262075  1.223818  1.219254  2.019504  10.250831  1.469649
#
#              APH_STE  NDSN_STE   CAH_NEM   CEG_NEM   DIS_NEM    IT_NEM  \
# Date
# 2022-02-23  0.326856  0.983616  0.781127  0.636250  2.170135  4.069952
# 2022-02-24  0.326426  0.963968  0.784539  0.671616  2.273621  4.282290
# 2022-02-25  0.322575  0.955513  0.796171  0.653839  2.236053  4.284883
# 2022-02-28  0.315486  0.940690  0.813754  0.702244  2.277063  4.301050
# 2022-03-01  0.311195  0.937899  0.763564  0.700168  2.143734  4.038225
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-17  0.376317  1.153705  1.539198  1.775056  2.735189  6.994432
# 2022-08-18  0.376562  1.154659  1.540873  1.827547  2.747368  7.054647
# 2022-08-19  0.377388  1.160846  1.590398  1.857110  2.759936  7.075121
# 2022-08-22  0.376850  1.135514  1.549749  1.817663  2.645824  6.927659
# 2022-08-23  0.382309  1.179573  1.535980  1.800135  2.600045  6.834310
#
#              NRG_NEM  SCHW_NEM    TT_NEM
# Date
# 2022-02-23  0.537846  1.220489  2.195844
# 2022-02-24  0.570192  1.244242  2.280275
# 2022-02-25  0.557495  1.274335  2.292504
# 2022-02-28  0.569553  1.287397  2.339218
# 2022-03-01  0.527591  1.138470  2.216707
# ...              ...       ...       ...
# 2022-08-17  0.948998  1.680624  3.706459
# 2022-08-18  0.974692  1.696528  3.739306
# 2022-08-19  0.986676  1.696761  3.760855
# 2022-08-22  0.960748  1.655637  3.642857
# 2022-08-23  0.946443  1.646064  3.557072
#
# [126 rows x 15 columns]

# %%
ratio = "ADP_SYK"

# %%
df = df_init[[ratio]]
df
# Out:
#              ADP_SYK
# Date
# 2022-02-23  0.771140
# 2022-02-24  0.774126
# 2022-02-25  0.766083
# 2022-02-28  0.773484
# 2022-03-01  0.767553
# ...              ...
# 2022-08-17  1.177302
# 2022-08-18  1.181579
# 2022-08-19  1.191070
# 2022-08-22  1.207346
# 2022-08-23  1.223818
#
# [126 rows x 1 columns]

# %%
train_size = 0.6
index = round(train_size*df.shape[0])

df_train = df.iloc[:index]
df_test = df.iloc[index:]

# %% [markdown]
# # Predict NEXT datapoint (1-month horizon)

# %%
y_pred = df_test.shift(1)

# %%
y_pred = df_test.shift(1).dropna()
y_true = df_test[1:]

print(f"R2: {r2_score(y_true, y_pred)}")
print(f"MAPE: {mean_absolute_percentage_error(y_true, y_pred)}")
# Out:
# R2: 0.9140493835231159
# MAPE: 0.009998990115849905

# %% [markdown]
# # Linear model with 35 autoregressive features

# %%
df2 = df.copy(); df2_train = df_train.copy(); df2_test = df_test.copy()
df2_train.head()
# Out:
#              ADP_SYK
# Date
# 2022-02-23  0.771140
# 2022-02-24  0.774126
# 2022-02-25  0.766083
# 2022-02-28  0.773484
# 2022-03-01  0.767553

# %%
len(df2_test)
# Out:
# 50

# %%
df2 = df.copy(); df2_train = df_train.copy(); df2_test = df_test.copy()

for i in range(1, 35):
    df2_train[f't - {i}'] = df_train[ratio].shift(i)
    df2_test[f't - {i}'] = df_test[ratio].shift(i)

df2_train.dropna(inplace=True)
df2_test.dropna(inplace=True)

df2_train
# Out:
#              ADP_SYK     t - 1     t - 2     t - 3     t - 4     t - 5  \
# Date
# 2022-04-12  0.879424  0.875973  0.881064  0.881702  0.885534  0.885326
# 2022-04-13  0.885508  0.879424  0.875973  0.881064  0.881702  0.885534
# 2022-04-14  0.874745  0.885508  0.879424  0.875973  0.881064  0.881702
# 2022-04-18  0.876287  0.874745  0.885508  0.879424  0.875973  0.881064
# 2022-04-19  0.844114  0.876287  0.874745  0.885508  0.879424  0.875973
# 2022-04-20  0.840672  0.844114  0.876287  0.874745  0.885508  0.879424
# 2022-04-21  0.851385  0.840672  0.844114  0.876287  0.874745  0.885508
# 2022-04-22  0.899069  0.851385  0.840672  0.844114  0.876287  0.874745
# 2022-04-25  0.893446  0.899069  0.851385  0.840672  0.844114  0.876287
# 2022-04-26  0.891962  0.893446  0.899069  0.851385  0.840672  0.844114
# 2022-04-27  0.913997  0.891962  0.893446  0.899069  0.851385  0.840672
# 2022-04-28  0.909957  0.913997  0.891962  0.893446  0.899069  0.851385
# 2022-04-29  0.903234  0.909957  0.913997  0.891962  0.893446  0.899069
# 2022-05-02  0.924391  0.903234  0.909957  0.913997  0.891962  0.893446
# 2022-05-03  0.930215  0.924391  0.903234  0.909957  0.913997  0.891962
# 2022-05-04  0.929386  0.930215  0.924391  0.903234  0.909957  0.913997
# 2022-05-05  0.904432  0.929386  0.930215  0.924391  0.903234  0.909957
# 2022-05-06  0.902515  0.904432  0.929386  0.930215  0.924391  0.903234
# 2022-05-09  0.914958  0.902515  0.904432  0.929386  0.930215  0.924391
# 2022-05-10  0.932185  0.914958  0.902515  0.904432  0.929386  0.930215
# 2022-05-11  0.918648  0.932185  0.914958  0.902515  0.904432  0.929386
# 2022-05-12  0.908891  0.918648  0.932185  0.914958  0.902515  0.904432
# 2022-05-09  0.807194  0.800681
# 2022-05-10  0.833182  0.807194
# 2022-05-11  0.825972  0.833182
# 2022-05-12  0.824555  0.825972
# 2022-05-13  0.817947  0.824555
# 2022-05-16  0.825180  0.817947
# 2022-05-17  0.845220  0.825180
# 2022-05-18  0.850057  0.845220
# 2022-05-19  0.866811  0.850057
# 2022-05-20  0.885989  0.866811
# 2022-05-23  0.885326  0.885989
# 2022-05-24  0.885534  0.885326
# 2022-05-25  0.881702  0.885534
# 2022-05-26  0.881064  0.881702
# 2022-05-27  0.875973  0.881064
# 2022-05-31  0.879424  0.875973
# 2022-06-01  0.885508  0.879424
# 2022-06-02  0.874745  0.885508
# 2022-06-03  0.876287  0.874745
# 2022-06-06  0.844114  0.876287
# 2022-06-07  0.840672  0.844114
# 2022-06-08  0.851385  0.840672
# 2022-06-09  0.899069  0.851385
# 2022-06-10  0.893446  0.899069
#
# [42 rows x 35 columns]

# %%
# Train Test Split
X2_train = df2_train.drop(columns = [ratio])
y2_train = df2_train[ratio]
X2_test = df2_test.drop(columns = [ratio])
y2_test = df2_test[ratio]

print(X2_train.shape,y2_train.shape, X2_test.shape,y2_test.shape)
# Out:
# (42, 34) (42,) (16, 34) (16,)

# %%
# Predict and measure R2
model = LinearRegression()
model = model.fit(X2_train, y2_train)

print('R2: ', r2_score(y2_test, model.predict(X2_test)))
pd.Series(model.coef_).plot(kind='bar')
plt.title('partial regression coefficients');
# Out:
# R2:  -10.020065824235918

# %% [markdown]
# # Predict a longer time horizon?

# %% [markdown]
# # Decomposition

# %%
df_init = pd.read_csv('/home/dellih/code/greengamma/long-short-trade-ideas-generator/notebooks/cleaned_data_test.csv')
df_init
# Out:
#            Date   TEL_BIO   ADP_SYK     ON_MU  ROST_VFC      CDW_T  PAYX_RTX  \
# 0    2022-02-23  0.239509  0.771140  0.663637  1.560298   9.729875  1.237427
# 1    2022-02-24  0.234301  0.774126  0.689893  1.592246  10.004847  1.227451
# 2    2022-02-25  0.223696  0.766083  0.707117  1.601182  10.073827  1.208059
# 3    2022-02-28  0.225564  0.773484  0.706936  1.594907   9.877013  1.158270
# 4    2022-03-01  0.217456  0.767553  0.693815  1.633461   9.768311  1.143246
# ..          ...       ...       ...       ...       ...        ...       ...
# 121  2022-08-17  0.258362  1.177302  1.108244  1.969446   9.914223  1.467810
# 122  2022-08-18  0.263737  1.181579  1.163068  1.972979  10.152469  1.469327
# 123  2022-08-19  0.264347  1.191070  1.198645  1.998024  10.220835  1.482762
# 124  2022-08-22  0.259488  1.207346  1.179901  2.042420  10.210149  1.481151
# 125  2022-08-23  0.262075  1.223818  1.219254  2.019504  10.250831  1.469649
#
#       APH_STE  NDSN_STE   CAH_NEM   CEG_NEM   DIS_NEM    IT_NEM   NRG_NEM  \
# 0    0.326856  0.983616  0.781127  0.636250  2.170135  4.069952  0.537846
# 1    0.326426  0.963968  0.784539  0.671616  2.273621  4.282290  0.570192
# 2    0.322575  0.955513  0.796171  0.653839  2.236053  4.284883  0.557495
# 2022-02-23  0.537846  1.220489  2.195844 2022-02-23
# 2022-02-24  0.570192  1.244242  2.280275 2022-02-24
# 2022-02-25  0.557495  1.274335  2.292504 2022-02-25
# 2022-02-28  0.569553  1.287397  2.339218 2022-02-28
# 2022-03-01  0.527591  1.138470  2.216707 2022-03-01
# ...              ...       ...       ...        ...
# 2022-08-17  0.948998  1.680624  3.706459 2022-08-17
# 2022-08-18  0.974692  1.696528  3.739306 2022-08-18
# 2022-08-19  0.986676  1.696761  3.760855 2022-08-19
# 2022-08-22  0.960748  1.655637  3.642857 2022-08-22
# 2022-08-23  0.946443  1.646064  3.557072 2022-08-23
#
# [126 rows x 16 columns]

# %%
df = df_init[[ratio]]
df
# Out:
#              ADP_SYK
# Date
# 2022-02-23  0.771140
# 2022-02-24  0.774126
# 2022-02-25  0.766083
# 2022-02-28  0.773484
# 2022-03-01  0.767553
# ...              ...
# 2022-08-17  1.177302
# 2022-08-18  1.181579
# 2022-08-19  1.191070
# 2022-08-22  1.207346
# 2022-08-23  1.223818
#
# [126 rows x 1 columns]

# %%
type(df[ratio])
# Out:
# pandas.core.series.Series

# %%
# Addititive Decomposition (y = Trend * Seasonal * Residuals)
result_add = seasonal_decompose(df[ratio], model="additive",period = 30)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,8)
result_add.plot();

# %%
# Multiplicative Decomposition (y = Trend * Seasonal * Residuals)
result_mul = seasonal_decompose(df[ratio], model="multiplicative",period = 30)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,8)
result_mul.plot();

# %%
# Plot the residuals with "result_add.resid" to decide
f, (ax1, ax2) = plt.subplots(1,2, figsize=(13,3))
ax1.plot(result_add.resid); ax1.set_title("Additive Model Residuals")
ax2.plot(result_mul.resid); ax2.set_title("Multiplicative Model Residuals");

# %% [markdown]
# # Stationarity

# %%
print('additive resid: ', adfuller(result_add.resid.dropna())[1])
print('multiplicative resid: ', adfuller(result_mul.resid.dropna())[1])
# Out:
# additive resid:  0.008438421856027738
# multiplicative resid:  0.012511302397532093

# %% [markdown]
# # Autocorrelation

# %%
plot_acf(df[ratio], lags=50)
plt.show()

# %%
plot_pacf(df[ratio], lags=50, c='r');
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
fig, axes = plt.subplots(1,2, figsize=(16,3))

plot_acf(df[ratio], lags=50, ax=axes[0]);
plot_pacf(df[ratio], lags=50, ax=axes[1], color='r');

# %% [markdown]
# # deseasonalized

# %% [markdown]
# 👉 We need to de-seasonalize our Time Series first, using our decomposition tool

# %%
# Let's remove seasons
plt.subplot(1,2,1); plt.plot(df[ratio])
plt.title('Bais', fontsize=16);

df['deseasonalized'] = df[ratio]/result_mul.seasonal

plt.figure(figsize=(15,4)); plt.subplot(1,2,2); plt.plot(df.deseasonalized);
plt.title('Deseasonalized', fontsize=16);
# Out:
# /tmp/ipykernel_2190/1321340137.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['deseasonalized'] = df[ratio]/result_mul.seasonal

# %%
# Let's difference this and look at the ACFs
fig, axes = plt.subplots(1, 3,figsize=(15,4))

axes[0].plot(df['deseasonalized']); axes[0].set_title('Series')
# 1st Differencing
y_diff = df['deseasonalized'].diff().dropna()
axes[1].plot(y_diff); axes[1].set_title('1st Order Differencing')

# 2nd Differencing
y_diff_diff = df['deseasonalized'].diff().diff().dropna()
axes[2].plot(y_diff_diff); axes[2].set_title('2nd Order Differencing');

# %%
# check with ADF Test for stationarity
print('p-value zero-diff: ', adfuller(df['deseasonalized'])[1])
print('p-value first-diff: ', adfuller(df['deseasonalized'].diff().dropna())[1])
print('p-value second-diff: ', adfuller(df['deseasonalized'].diff().diff().dropna())[1])
# Out:
# p-value zero-diff:  0.9772755932160903
# p-value first-diff:  6.057653822869861e-18
# p-value second-diff:  1.0587518225824652e-06

# %% [markdown]
# ☝️ We should select d=1

# %% [markdown]
# # test Arima

# %%
smodel = pm.auto_arima(df["deseasonalized"],
                       start_p=1, max_p=6,
                       start_q=1, max_q=6,
                       trend='t',
                       max_d = 2,
                       seasonal=False,
                       trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-731.820, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-734.505, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-733.299, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-733.409, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-734.505, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 0.192 seconds

# %%
arima = ARIMA(df["deseasonalized"], order=(0, 1, 0), trend='t')
arima = arima.fit()
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:         deseasonalized   No. Observations:                  126
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 369.285
# Date:                Sat, 27 Aug 2022   AIC                           -734.571
# Time:                        15:23:59   BIC                           -728.914
# Sample:                             0   HQIC                          -732.273
#                                 - 126
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0036      0.001      3.093      0.002       0.001       0.006
# sigma2         0.0002   1.61e-05      9.860      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.79   Jarque-Bera (JB):                12.40
# Prob(Q):                              0.38   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                             0.42
# Prob(H) (two-sided):                  0.72   Kurtosis:                         4.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.graphics.tsaplots import plot_predict

fig, axs = plt.subplots(1, 1, figsize=(20, 10))
axs.plot(df["deseasonalized"], label='basis')
plot_predict(arima, start=1, end=140, ax=axs);
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Build model
arima = ARIMA(df_train, order=(0, 1, 0), trend='t')  
arima = arima.fit()

## Forecast
# Forecast values
forecast = arima.forecast(len(df_test), alpha=0.05)  # 95% confidence

# Forecast values and confidence intervals
forecast_results = arima.get_forecast(len(df_test), alpha=0.05)
forecast = forecast_results.predicted_mean
confidence_int = forecast_results.conf_int()
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
forecast_df = pd.DataFrame(forecast)
forecast_df["id"] = list(df_test.index)
forecast_df.set_index("id",inplace=True)

# %%
confidence_int["id"] = list(df_test.index)
confidence_int.set_index("id",inplace=True)
confidence_int= np.array(confidence_int)

# %%
# We define here a "Plot forecast vs. real", which also shows historical training set

def plot_forecast(fc, train, test, upper=None, lower=None):
    is_confidence_int = isinstance(upper, np.ndarray) and isinstance(lower, np.ndarray)
    # Prepare plot series
    #fc_series = pd.Series(fc, index=test.index)
    
    lower_series = pd.Series(upper,index=test.index) if is_confidence_int else None
    upper_series = pd.Series(lower,index=test.index) if is_confidence_int else None
    
    # Plot
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(train, label='training', color='black')
    plt.plot(test, label='actual', color='black', ls='--')
    plt.plot(fc, label='forecast', color='orange')
    if is_confidence_int:
        plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8);

# %%
plot_forecast(forecast_df, df_train, df_test, confidence_int[:,0], confidence_int[:,1])

# %%
# Re-compose back to initial TS

forecast_recons = forecast_df["predicted_mean"] * result_mul.seasonal[76:]
train_recons = df_train[ratio] * result_mul.seasonal[0:76]
test_recons = df_test[ratio] * result_mul.seasonal[76:]
lower_recons = confidence_int[:, 0] * result_mul.seasonal[76:]
upper_recons = confidence_int[:, 1] * result_mul.seasonal[76:]

# Plot
plot_forecast(forecast_recons, train_recons, test_recons, lower_recons.values, upper_recons.values)

# %%
mape_arima_deseasonalized = np.mean(np.abs(forecast_recons - test_recons)/np.abs(test_recons))
mape_arima_deseasonalized
# Out:
# 0.0449732059367389

# %% [markdown]
# # Auto Regressive Integrated Moving Average - ARIMA

# %%
zero_diff = df[ratio]
first_order_diff = df[ratio].diff(1)
second_order_diff = df[ratio].diff(1).diff(1)


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,4))
ax1.plot(zero_diff); ax1.set_title('Original Series')
ax2.plot(first_order_diff); ax2.set_title('1st Order Differencing')
ax3.plot(second_order_diff); ax3.set_title('2nd Order Differencing');

# %%
smodel = pm.auto_arima(df[ratio],
                       start_p=1, max_p=6,
                       start_q=1, max_q=6,
                       trend='t',
                       max_d = 2,
                       seasonal=False,
                       trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-722.201, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-725.061, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-723.176, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-723.162, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-725.061, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.203 seconds

# %%
arima = ARIMA(df[ratio], order=(0, 1, 0), trend='t')
arima = arima.fit()
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
arima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                ADP_SYK   No. Observations:                  126
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 364.598
# Date:                Sat, 27 Aug 2022   AIC                           -725.195
# Time:                        15:24:05   BIC                           -719.539
# Sample:                             0   HQIC                          -722.897
#                                 - 126
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0036      0.001      2.985      0.003       0.001       0.006
# sigma2         0.0002   1.81e-05      9.492      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):                10.34
# Prob(Q):                              0.74   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.90   Skew:                             0.45
# Prob(H) (two-sided):                  0.72   Kurtosis:                         4.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Evaluate Performance

# %%
from statsmodels.graphics.tsaplots import plot_predict

fig, axs = plt.subplots(1, 1, figsize=(20, 10))
axs.plot(df[ratio], label='basis')
plot_predict(arima, start=1, end=140, ax=axs);
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Build model
arima = ARIMA(df_train, order=(0, 1, 0), trend='t')  
arima = arima.fit()

## Forecast
# Forecast values
forecast = arima.forecast(len(df_test), alpha=0.05)  # 95% confidence

# Forecast values and confidence intervals
forecast_results = arima.get_forecast(len(df_test), alpha=0.05)
forecast = forecast_results.predicted_mean
confidence_int = forecast_results.conf_int()
# Out:
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
forecast_df = pd.DataFrame(forecast)

# %%
forecast_df["id"] = list(df_test.index)
forecast_df.set_index("id",inplace=True)

# %%
confidence_int["id"] = list(df_test.index)
confidence_int.set_index("id",inplace=True)
confidence_int= np.array(confidence_int)

# %%
# We define here a "Plot forecast vs. real", which also shows historical training set

def plot_forecast(fc, train, test, upper=None, lower=None):
    is_confidence_int = isinstance(upper, np.ndarray) and isinstance(lower, np.ndarray)
    # Prepare plot series
    #fc_series = pd.Series(fc, index=test.index)
    
    lower_series = pd.Series(upper,index=test.index) if is_confidence_int else None
    upper_series = pd.Series(lower,index=test.index) if is_confidence_int else None
    
    # Plot
    plt.figure(figsize=(10,4), dpi=100)
    plt.plot(train, label='training', color='black')
    plt.plot(test, label='actual', color='black', ls='--')
    plt.plot(fc, label='forecast', color='orange')
    if is_confidence_int:
        plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
    plt.title('Forecast vs Actuals')
    plt.legend(loc='upper left', fontsize=8);

# %%
plot_forecast(forecast_df, df_train, df_test, confidence_int[:,0], confidence_int[:,1])

# %%
mape_arima = np.mean(np.abs(forecast_df["predicted_mean"] - df_test[ratio])/np.abs(df_test[ratio]))
mape_arima
# Out:
# 0.0449732059367389

# %% [markdown]
# # Sarima

# %%
smodel = pm.auto_arima(df_train, seasonal=True, m=12, 
                       start_p=0, max_p=1, max_d=1, start_q=0, max_q=1,
                       start_P=0, max_P=2, max_D=1, start_Q=0, max_Q=2, 
                       trace=True, error_action='ignore', suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-435.210, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-434.284, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-434.474, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-433.774, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-434.408, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-434.357, Time=0.09 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-432.417, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-434.568, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-434.843, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-432.924, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12] intercept
# Total fit time: 0.837 seconds

# %%
smodel.get_params
# Out:
# <bound method BaseEstimator.get_params of ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Build Model
sarima = SARIMAX(df_train, order=(0, 1, 1), seasonal_order=(2, 0, 2, 12))
sarima = sarima.fit(maxiter=75)

# Forecast
results = sarima.get_forecast(len(df_test), alpha=0.05)
forecast = results.predicted_mean
confidence_int = results.conf_int()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.88326D+00    |proj g|=  2.81596D+00
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# At iterate    5    f= -2.88480D+00    |proj g|=  3.93488D+00
#
# At iterate   10    f= -2.89779D+00    |proj g|=  5.64603D-01
#
# At iterate   15    f= -2.89789D+00    |proj g|=  1.00388D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     18     28      1     0     0   6.802D-03  -2.898D+00
#   F =  -2.8978948193369041
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /home/dellih/.pyenv/versions/3.8.12/envs/long-short-trade-ideas-generator/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
forecast_df = pd.DataFrame(forecast)

# %%
forecast_df["id"] = list(df_test.index)
forecast_df.set_index("id",inplace=True)

# %%
confidence_int["id"] = list(df_test.index)
confidence_int.set_index("id",inplace=True)
confidence_int= np.array(confidence_int)

# %%
plot_forecast(forecast, df_train, df_test, confidence_int[:,0], confidence_int[:,1])

# %%
sarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                 ADP_SYK   No. Observations:                   76
# Model:             SARIMAX(0, 1, 1)x(2, 0, [1, 2], 12)   Log Likelihood                 220.240
# Date:                                 Sat, 27 Aug 2022   AIC                           -428.480
# Time:                                         15:24:09   BIC                           -414.575
# Sample:                                              0   HQIC                          -422.928
#                                                   - 76
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2001      0.154      1.299      0.194      -0.102       0.502
# ar.S.L12       0.0854     21.813      0.004      0.997     -42.667      42.838
# ar.S.L24       0.0241      7.022      0.003      0.997     -13.740      13.788
# ma.S.L12       0.0880     21.774      0.004      0.997     -42.588      42.764
# ma.S.L24       0.0207      3.297      0.006      0.995      -6.440       6.482
# sigma2         0.0002   2.09e-05      7.825      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                14.66
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.71   Skew:                             0.56
# Prob(H) (two-sided):                  0.40   Kurtosis:                         4.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
mape_sarima = np.mean(np.abs(forecast_df["predicted_mean"] - df_test[ratio])/np.abs(df_test[ratio]))
mape_sarima
# Out:
# 0.09766896622725353
