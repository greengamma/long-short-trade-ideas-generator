# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import data
df = pd.read_csv(r'cleaned_data.csv')
df.head()
# Out:
#          Date  ALB_ZBRA  NRG_CPRT    DE_BXP   NRG_STE  NRG_XRAY   SO_NLOK  \
# 0  2020-08-31  0.311845  0.310544  2.548054  0.203834  0.727693  2.136432
# 1  2020-09-01  0.332974  0.306303  2.687319  0.203522  0.722940  2.094566
# 2  2020-09-02  0.332368  0.315056  2.629334  0.204743  0.734758  2.125291
# 3  2020-09-03  0.339772  0.310060  2.534974  0.201707  0.728923  2.210971
# 4  2020-09-04  0.356920  0.300754  2.536138  0.199887  0.707646  2.152835
#
#       PEG_O
# 0  0.882281
# 1  0.855546
# 2  0.872526
# 3  0.848504
# 4  0.854765

# %%
df.tail(2)
# Out:
#            Date  ALB_ZBRA  NRG_CPRT   DE_BXP   NRG_STE  NRG_XRAY   SO_NLOK  \
# 495  2022-08-18  0.816374  0.333768  4.22249  0.204492  1.196920  3.371537
# 496  2022-08-19  0.822204  0.334919  4.28095  0.204631  1.200391  3.405268
#
#         PEG_O
# 495  0.950678
# 496  0.951858

# %%
df.describe()
# Out:
#          ALB_ZBRA    NRG_CPRT      DE_BXP     NRG_STE    NRG_XRAY     SO_NLOK  \
# count  497.000000  497.000000  497.000000  497.000000  497.000000  497.000000
# mean     0.439148    0.296925    3.242148    0.178814    0.728099    2.664304
# std      0.134129    0.038166    0.309264    0.017806    0.170586    0.296301
# min      0.279760    0.219809    2.513787    0.147486    0.464028    2.094566
# 25%      0.336085    0.270483    3.054503    0.164950    0.624090    2.436779
# 50%      0.403014    0.290112    3.224409    0.175372    0.691772    2.649792
# 75%      0.464571    0.316606    3.435012    0.189553    0.742545    2.861494
# max      0.822204    0.425462    4.280950    0.231046    1.230987    3.405268
#
#             PEG_O
# count  497.000000
# mean     0.960830
# std      0.047787
# min      0.829956
# 25%      0.928549
# 50%      0.960627
# 75%      0.994654
# max      1.094158

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      497 non-null    object
#  1   ALB_ZBRA  497 non-null    float64
#  2   NRG_CPRT  497 non-null    float64
#  3   DE_BXP    497 non-null    float64
#  4   NRG_STE   497 non-null    float64
#  5   NRG_XRAY  497 non-null    float64
#  6   SO_NLOK   497 non-null    float64
#  7   PEG_O     497 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 31.2+ KB

# %%
df.shape
# Out:
# (497, 8)

# %%
# we check first chosen ratios first (here: ALB_ZBRA)
df_small=df.iloc[:,[0,1]]
df_small.head()
# Out:
#          Date  ALB_ZBRA
# 0  2020-08-31  0.311845
# 1  2020-09-01  0.332974
# 2  2020-09-02  0.332368
# 3  2020-09-03  0.339772
# 4  2020-09-04  0.356920

# %%
df_small.shape
# Out:
# (497, 2)

# %%
df_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      497 non-null    object
#  1   ALB_ZBRA  497 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ## Splitting Data in Train and Validation

# %%
length_data = len(df_small)    
split_ratio = 0.7           # %70 train + %30 validation
length_train = round(length_data * split_ratio)  
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length:", length_train)
print("Validation data lenth:", length_validation)
# Out:
# Data length : 497
# Train data length: 348
# Validation data lenth: 149

# %%
# train_data
train_data = df_small[:length_train].iloc[:,:2] 
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#           Date  ALB_ZBRA
# 0   2020-08-31  0.311845
# 1   2020-09-01  0.332974
# 2   2020-09-02  0.332368
# 3   2020-09-03  0.339772
# 4   2020-09-04  0.356920
# ..         ...       ...
# 343 2022-01-10  0.422384
# 344 2022-01-11  0.444326
# 345 2022-01-12  0.446099
# 346 2022-01-13  0.445756
# 347 2022-01-14  0.440955
#
# [348 rows x 2 columns]

# %%
# validation_data
validation_data = df_small[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#           Date  ALB_ZBRA
# 348 2022-01-18  0.436370
# 349 2022-01-19  0.426604
# 350 2022-01-20  0.431503
# 351 2022-01-21  0.428953
# 352 2022-01-24  0.430432
# ..         ...       ...
# 492 2022-08-15  0.813028
# 493 2022-08-16  0.814154
# 494 2022-08-17  0.815450
# 495 2022-08-18  0.816374
# 496 2022-08-19  0.822204
#
# [149 rows x 2 columns]

# %% [markdown]
# ## Creating Train Dataset from Train split

# %%
dataset_train = train_data.ALB_ZBRA.values
dataset_train.shape
# Out:
# (348,)

# %%
# Change 1d array to 2d array
# Changing shape from (1692,) to (1692,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (348, 1)

# %% [markdown]
# ## Normalization / Feature Scaling

# %%
# Dataset values will be in between 0 and 1 after scaling

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler(feature_range = (0,1))

# scaling dataset
#dataset_train_scaled = scaler.fit_transform(dataset_train)

#dataset_train_scaled.shape

dataset_train_scaled = dataset_train

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days 1st, 2nd, 3rd..")
plt.ylabel("Ratio")
plt.show()

# %% [markdown]
# ## Creating X_train and y_train from Train data

# %% [markdown]
# We have train data composed of ratios over days
#
# So, it has 1184 ratios corresponding 1184 days
#
# My aim is to predict the ratio (closing) of the next day.
#
# I can use a time step of 2 days.
#
# I will pick first 2 ratios (day 0 to 2), 1st 2 ratio will be in
# X_train data
#
# Then predict the ratio of 3rd day; and 3rd ratio will be in y_train data
#
# Again, i will pick ratios from 1 to 3, those will be in X_train data
#
# Then predict the next days ratio, 4th ratio will be in y_train data

# %%
#question: which time step makes sense?

X_train = []
y_train = []

time_step = 20 #change that?

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0:1])
    y_train.append(dataset_train_scaled[i,0:1])
    
# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (328, 20, 1)

# %%
pd.Series([len(X) for X in X_train]).describe()
# Out:
# count    328.0
# mean      20.0
# std        0.0
# min       20.0
# 25%       20.0
# 50%       20.0
# 75%       20.0
# max       20.0
# dtype: float64

# %%
dataset_train_scaled[i-time_step:i]
# Out:
# array([[0.38862944],
#        [0.38917616],
#        [0.38077796],
#        [0.38492726],
#        [0.38663534],
#        [0.38988871],
#        [0.3830526 ],
#        [0.38833012],
#        [0.38542777],
#        [0.39077174],
#        [0.39133709],
#        [0.4038591 ],
#        [0.41133758],
#        [0.42062969],
#        [0.41886172],
#        [0.44299006],
#        [0.42238371],
#        [0.44432603],
#        [0.44609879],
#        [0.44575611]])

# %%
dataset_train_scaled[i,0]
# Out:
# 0.4409549019553445

# %%
print("Shape of X_train before reshape:",X_train.shape)
print("Shape of y_train before reshape:",y_train.shape)
# Out:
# Shape of X_train before reshape: (328, 20, 1)
# Shape of y_train before reshape: (328, 1)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (328, 20, 1)
# Shape of y_train after reshape : (328, 1)

# %%
X_train[0]
# Out:
# array([[0.31184533],
#        [0.33297423],
#        [0.33236771],
#        [0.33977172],
#        [0.35692005],
#        [0.36686296],
#        [0.36722494],
#        [0.36801524],
#        [0.3729842 ],
#        [0.38359747],
#        [0.3751988 ],
#        [0.37780616],
#        [0.38648978],
#        [0.37695343],
#        [0.37698369],
#        [0.37210869],
#        [0.31760517],
#        [0.32758807],
#        [0.32358099],
#        [0.32094169]])

# %%
X_train = X_train[:int(X_train.shape[0]*0.95)]
X_val = X_train[int(X_train.shape[0]*0.95):]
y_train = y_train[:int(y_train.shape[0]*0.95)]
y_val = y_train[int(y_train.shape[0]*0.95):]

# %% [markdown]
# Check the first item in y_train
# It is the ratio of 2nd day (timestep 2)

# %%
y_train[0]
# Out:
# array([0.3306644])

# %% [markdown]
# ## Creating RNN model

# %%
### open questions
#### makes the combination of RNN, LSTM and GRU sense?

# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

# adding second RNN layer and dropout regulatization
#regressor.add(SimpleRNN(units = 50, activation = "tanh",return_sequences = True))
#regressor.add(Dropout(0.2))

# adding third RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50,activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2))

# adding fourth RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50))
regressor.add(Dropout(0.2))

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(optimizer = "rmsprop", loss = "mean_squared_error",metrics = ["mae", "mape"]) #rmsprop as optimizer for RNN?

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data=(X_val, y_val))
# Out:
# 2022-09-03 14:40:38.935772: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-03 14:40:39.078775: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 10/10 [==============================] - 20s 104ms/step - loss: 0.7103 - mae: 0.6577 - mape: 180.8617 - val_loss: 0.0151 - val_mae: 0.1216 - val_mape: 29.5129
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2597 - mae: 0.4207 - mape: 116.2889 - val_loss: 0.0158 - val_mae: 0.1251 - val_mape: 30.2690
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2594 - mae: 0.4052 - mape: 114.4790 - val_loss: 0.0138 - val_mae: 0.1161 - val_mape: 28.1637
# Epoch 4/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1782 - mae: 0.3400 - mape: 92.8753 - val_loss: 0.0010 - val_mae: 0.0284 - val_mape: 7.0121
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1316 - mae: 0.2925 - mape: 81.9308 - val_loss: 0.0208 - val_mae: 0.1429 - val_mape: 34.1592
# Epoch 6/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1079 - mae: 0.2632 - mape: 72.4652 - val_loss: 6.5262e-04 - val_mae: 0.0200 - val_mape: 4.9326
# Epoch 7/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0868 - mae: 0.2350 - mape: 64.5760 - val_loss: 0.0357 - val_mae: 0.1872 - val_mape: 45.4013
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0812 - mae: 0.2277 - mape: 62.1426 - val_loss: 0.0014 - val_mae: 0.0353 - val_mape: 8.3608
# Epoch 9/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0587 - mae: 0.1928 - mape: 53.6115 - val_loss: 0.0171 - val_mae: 0.1301 - val_mape: 31.1838
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0518 - mae: 0.1745 - mape: 48.1208 - val_loss: 0.0861 - val_mae: 0.2927 - val_mape: 70.2803
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0945 - mae: 0.2530 - mape: 68.7894 - val_loss: 0.0048 - val_mae: 0.0672 - val_mape: 15.9863
# Epoch 12/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0348 - mae: 0.1500 - mape: 40.9783 - val_loss: 9.2597e-04 - val_mae: 0.0251 - val_mape: 5.8352
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0368 - mae: 0.1533 - mape: 42.3659 - val_loss: 5.5217e-04 - val_mae: 0.0198 - val_mape: 4.6550
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0245 - mae: 0.1264 - mape: 34.9408 - val_loss: 0.0032 - val_mae: 0.0540 - val_mape: 13.2060
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0269 - mae: 0.1293 - mape: 36.2923 - val_loss: 4.8954e-04 - val_mae: 0.0181 - val_mape: 4.5125
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0207 - mae: 0.1178 - mape: 32.1850 - val_loss: 4.4353e-04 - val_mae: 0.0176 - val_mape: 4.1078
# Epoch 17/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0218 - mae: 0.1160 - mape: 32.1837 - val_loss: 2.6371e-04 - val_mae: 0.0125 - val_mape: 3.1047
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0179 - mae: 0.1087 - mape: 29.8636 - val_loss: 0.0012 - val_mae: 0.0303 - val_mape: 7.4854
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - mae: 0.0887 - mape: 24.2113 - val_loss: 2.7724e-04 - val_mae: 0.0129 - val_mape: 3.1904
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0808 - mape: 22.0792 - val_loss: 0.0016 - val_mae: 0.0360 - val_mape: 8.8710
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0139 - mae: 0.0960 - mape: 26.7366 - val_loss: 0.0021 - val_mae: 0.0437 - val_mape: 10.6916
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0092 - mae: 0.0736 - mape: 19.7760 - val_loss: 4.9951e-04 - val_mae: 0.0180 - val_mape: 4.5071
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0095 - mae: 0.0804 - mape: 21.9430 - val_loss: 3.0693e-04 - val_mae: 0.0139 - val_mape: 3.4751
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0072 - mae: 0.0661 - mape: 18.2345 - val_loss: 4.5227e-04 - val_mae: 0.0166 - val_mape: 4.1670
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0067 - mae: 0.0655 - mape: 17.9974 - val_loss: 0.0027 - val_mae: 0.0507 - val_mape: 12.3527
# Epoch 26/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0088 - mae: 0.0727 - mape: 19.8728 - val_loss: 9.9680e-04 - val_mae: 0.0294 - val_mape: 7.2233
# Epoch 27/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0069 - mae: 0.0675 - mape: 18.7197 - val_loss: 7.0268e-04 - val_mae: 0.0241 - val_mape: 5.9457
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0054 - mae: 0.0575 - mape: 15.6902 - val_loss: 5.5515e-04 - val_mae: 0.0203 - val_mape: 4.7401
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - mae: 0.0583 - mape: 15.8636 - val_loss: 1.4250e-04 - val_mae: 0.0106 - val_mape: 2.5598
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0041 - mae: 0.0526 - mape: 14.3366 - val_loss: 0.0030 - val_mae: 0.0541 - val_mape: 13.1638
# Epoch 31/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0071 - mae: 0.0676 - mape: 18.4422 - val_loss: 1.2684e-04 - val_mae: 0.0100 - val_mape: 2.4020
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0041 - mae: 0.0506 - mape: 13.6568 - val_loss: 0.0047 - val_mae: 0.0681 - val_mape: 16.5008
# Epoch 33/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mae: 0.0594 - mape: 16.1656 - val_loss: 3.5136e-04 - val_mae: 0.0164 - val_mape: 3.8497
# Epoch 34/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0051 - mae: 0.0580 - mape: 15.6339 - val_loss: 0.0040 - val_mae: 0.0622 - val_mape: 15.0732
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0040 - mae: 0.0521 - mape: 14.3873 - val_loss: 0.0093 - val_mae: 0.0958 - val_mape: 22.9418
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - mae: 0.0620 - mape: 16.5614 - val_loss: 6.7603e-04 - val_mae: 0.0244 - val_mape: 5.9734
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - mae: 0.0427 - mape: 11.7413 - val_loss: 3.2963e-04 - val_mae: 0.0157 - val_mape: 3.8885
# Epoch 38/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - mae: 0.0454 - mape: 12.4669 - val_loss: 4.6646e-04 - val_mae: 0.0198 - val_mape: 4.6929
# Epoch 39/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0435 - mape: 11.9872 - val_loss: 0.0014 - val_mae: 0.0366 - val_mape: 8.8979
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0416 - mape: 11.4949 - val_loss: 0.0014 - val_mae: 0.0365 - val_mape: 8.7032
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0412 - mape: 11.2767 - val_loss: 5.9616e-04 - val_mae: 0.0230 - val_mape: 5.4634
# Epoch 42/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0042 - mae: 0.0534 - mape: 14.4703 - val_loss: 5.1400e-05 - val_mae: 0.0057 - val_mape: 1.3715
# Epoch 43/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0413 - mape: 11.2900 - val_loss: 8.3074e-05 - val_mae: 0.0075 - val_mape: 1.8366
# Epoch 44/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0377 - mape: 10.3898 - val_loss: 0.0014 - val_mae: 0.0361 - val_mape: 8.7427
# Epoch 45/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0359 - mape: 9.9146 - val_loss: 3.0301e-04 - val_mae: 0.0157 - val_mape: 3.7105
# Epoch 46/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0462 - mape: 12.4147 - val_loss: 3.8569e-04 - val_mae: 0.0182 - val_mape: 4.4514
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0415 - mape: 11.3295 - val_loss: 0.0014 - val_mae: 0.0368 - val_mape: 8.9268
# Epoch 48/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0019 - mae: 0.0352 - mape: 9.8090 - val_loss: 0.0056 - val_mae: 0.0745 - val_mape: 17.9899
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - mae: 0.0481 - mape: 12.8204 - val_loss: 0.0015 - val_mae: 0.0379 - val_mape: 9.0289
# Epoch 50/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0407 - mape: 11.1916 - val_loss: 0.0033 - val_mae: 0.0574 - val_mape: 13.8788
# Epoch 51/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0029 - mae: 0.0442 - mape: 12.1426 - val_loss: 1.2950e-04 - val_mae: 0.0097 - val_mape: 2.3809
# Epoch 52/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0381 - mape: 10.3388 - val_loss: 0.0015 - val_mae: 0.0381 - val_mape: 9.2160
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0343 - mape: 9.3042 - val_loss: 7.0407e-04 - val_mae: 0.0256 - val_mape: 6.2267
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - mae: 0.0328 - mape: 8.9260 - val_loss: 8.7533e-04 - val_mae: 0.0288 - val_mape: 6.9728
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0370 - mape: 9.9630 - val_loss: 7.3404e-05 - val_mae: 0.0069 - val_mape: 1.7079
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0286 - mape: 7.8530 - val_loss: 7.0985e-04 - val_mae: 0.0257 - val_mape: 6.2385
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0301 - mape: 8.2435 - val_loss: 5.4273e-04 - val_mae: 0.0222 - val_mape: 5.3960
# Epoch 58/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0282 - mape: 7.6003 - val_loss: 5.6562e-05 - val_mae: 0.0063 - val_mape: 1.4910
# Epoch 59/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0315 - mape: 8.5499 - val_loss: 5.5433e-04 - val_mae: 0.0221 - val_mape: 5.2499
# Epoch 60/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0015 - mae: 0.0307 - mape: 8.2247 - val_loss: 0.0013 - val_mae: 0.0352 - val_mape: 8.5362
# Epoch 61/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mae: 0.0362 - mape: 9.8919 - val_loss: 1.1521e-04 - val_mae: 0.0087 - val_mape: 2.1414
# Epoch 62/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0281 - mape: 7.6627 - val_loss: 7.5794e-05 - val_mae: 0.0074 - val_mape: 1.7663
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0298 - mape: 8.1743 - val_loss: 1.2451e-04 - val_mae: 0.0092 - val_mape: 2.1822
# Epoch 64/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0275 - mape: 7.4554 - val_loss: 6.3343e-04 - val_mae: 0.0241 - val_mape: 5.7421
# Epoch 65/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0318 - mape: 8.6878 - val_loss: 4.6999e-04 - val_mae: 0.0204 - val_mape: 4.9542
# Epoch 66/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0312 - mape: 8.5130 - val_loss: 1.4562e-04 - val_mae: 0.0104 - val_mape: 2.5424
# Epoch 67/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0266 - mape: 7.2781 - val_loss: 1.1590e-04 - val_mae: 0.0089 - val_mape: 2.1201
# Epoch 68/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0253 - mape: 6.8623 - val_loss: 6.9487e-05 - val_mae: 0.0072 - val_mape: 1.7081
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0276 - mape: 7.5134 - val_loss: 0.0036 - val_mae: 0.0589 - val_mape: 14.1092
# Epoch 70/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0302 - mape: 8.0809 - val_loss: 0.0032 - val_mae: 0.0562 - val_mape: 13.4656
# Epoch 71/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mae: 0.0355 - mape: 9.5326 - val_loss: 0.0026 - val_mae: 0.0499 - val_mape: 11.9588
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0276 - mape: 7.4807 - val_loss: 2.4123e-04 - val_mae: 0.0139 - val_mape: 3.3171
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0011 - mae: 0.0263 - mape: 7.1883 - val_loss: 7.4974e-04 - val_mae: 0.0264 - val_mape: 6.3873
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0238 - mape: 6.4913 - val_loss: 2.2318e-04 - val_mae: 0.0133 - val_mape: 3.2651
# Epoch 75/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0281 - mape: 7.6072 - val_loss: 9.3070e-04 - val_mae: 0.0297 - val_mape: 7.1757
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0015 - mae: 0.0318 - mape: 8.6663 - val_loss: 1.1266e-04 - val_mae: 0.0087 - val_mape: 2.1209
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.2397e-04 - mae: 0.0241 - mape: 6.5133 - val_loss: 8.6662e-04 - val_mae: 0.0285 - val_mape: 6.8027
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0305 - mape: 8.3019 - val_loss: 6.7134e-05 - val_mae: 0.0068 - val_mape: 1.6304
# Epoch 79/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - mae: 0.0270 - mape: 7.3888 - val_loss: 1.6683e-04 - val_mae: 0.0109 - val_mape: 2.5790
# Epoch 80/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.6524e-04 - mae: 0.0221 - mape: 5.9327 - val_loss: 3.3457e-04 - val_mae: 0.0168 - val_mape: 4.0922
# Epoch 81/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - mae: 0.0304 - mape: 8.2179 - val_loss: 6.4471e-04 - val_mae: 0.0243 - val_mape: 5.9018
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0251 - mape: 6.7393 - val_loss: 1.4874e-04 - val_mae: 0.0102 - val_mape: 2.4138
# Epoch 83/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0273 - mape: 7.2658 - val_loss: 1.7878e-04 - val_mae: 0.0114 - val_mape: 2.7119
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - mae: 0.0259 - mape: 6.8580 - val_loss: 1.6547e-04 - val_mae: 0.0112 - val_mape: 2.7366
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - mae: 0.0278 - mape: 7.4622 - val_loss: 3.3191e-04 - val_mae: 0.0167 - val_mape: 4.0767
# Epoch 86/100
# 10/10 [==============================] - 0s 8ms/step - loss: 8.7682e-04 - mae: 0.0232 - mape: 6.3345 - val_loss: 0.0015 - val_mae: 0.0374 - val_mape: 8.9329
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0314 - mape: 8.4125 - val_loss: 2.5807e-04 - val_mae: 0.0145 - val_mape: 3.5301
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.5954e-04 - mae: 0.0253 - mape: 6.9702 - val_loss: 6.0581e-05 - val_mae: 0.0068 - val_mape: 1.6361
# Epoch 89/100
# 10/10 [==============================] - 0s 7ms/step - loss: 8.9597e-04 - mae: 0.0240 - mape: 6.5014 - val_loss: 9.6968e-04 - val_mae: 0.0303 - val_mape: 7.3411
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0013 - mae: 0.0287 - mape: 7.8571 - val_loss: 7.8362e-05 - val_mae: 0.0078 - val_mape: 1.8522
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 9.0830e-04 - mae: 0.0233 - mape: 6.3878 - val_loss: 8.5825e-04 - val_mae: 0.0284 - val_mape: 6.8659
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0011 - mae: 0.0267 - mape: 7.2686 - val_loss: 1.2674e-04 - val_mae: 0.0095 - val_mape: 2.2875
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.7601e-04 - mae: 0.0220 - mape: 6.0539 - val_loss: 9.3105e-04 - val_mae: 0.0296 - val_mape: 7.0826
# Epoch 94/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.3671e-04 - mae: 0.0211 - mape: 5.7192 - val_loss: 0.0018 - val_mae: 0.0424 - val_mape: 10.2186
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mae: 0.0308 - mape: 8.4998 - val_loss: 3.4985e-04 - val_mae: 0.0174 - val_mape: 4.2015
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0010 - mae: 0.0264 - mape: 7.1834 - val_loss: 3.7458e-04 - val_mae: 0.0182 - val_mape: 4.4002
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 9.1086e-04 - mae: 0.0239 - mape: 6.4683 - val_loss: 7.5178e-05 - val_mae: 0.0068 - val_mape: 1.6426
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.0410e-04 - mae: 0.0202 - mape: 5.4114 - val_loss: 6.3175e-04 - val_mae: 0.0242 - val_mape: 5.7980
# Epoch 99/100
# 10/10 [==============================] - 0s 7ms/step - loss: 8.9859e-04 - mae: 0.0239 - mape: 6.4770 - val_loss: 5.1971e-05 - val_mae: 0.0063 - val_mape: 1.5065
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 7.3211e-04 - mae: 0.0209 - mape: 5.7008 - val_loss: 1.4973e-04 - val_mae: 0.0104 - val_mape: 2.4505

# %% [markdown]
# ## Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.539574384689331,
#  0.23743435740470886,
#  0.27427956461906433,
#  0.15162308514118195,
#  0.1293250024318695,
#  0.1021469458937645,
#  0.10609107464551926,
#  0.07144850492477417,
#  0.05410989746451378,
#  0.04748295992612839,
#  0.07543792575597763,
#  0.03512967377901077,
#  0.04230881482362747,
#  0.022657684981822968,
#  0.027874315157532692,
#  0.018470168113708496,
#  0.023611191660165787,
#  0.017776191234588623,
#  0.012219893746078014,
#  0.011388699524104595,
#  0.012903198599815369,
#  0.010709203779697418,
#  0.009308621287345886,
#  0.007591830100864172,
#  0.007435767911374569,
#  0.007682546507567167,
#  0.00774779636412859,
#  0.007105811964720488,
#  0.005423033144325018,
#  0.004198756068944931,
#  0.006764025427401066,
#  0.0045632049441337585,
#  0.004397296346724033,
#  0.004648790694773197,
#  0.0035773259587585926,
#  0.005500359460711479,
#  0.0027951665688306093,
#  0.003953990060836077,
#  0.0035762530751526356,
#  0.002747589722275734,
#  0.002292899414896965,
#  0.0037682696711272,
#  0.0027525227051228285,
#  0.002505671698600054,
#  0.0018837259849533439,
#  0.0031685009598731995,
#  0.0029533752240240574,
#  0.001892701955512166,
#  0.0023445996921509504,
#  0.002140715252608061,
#  0.0023367248941212893,
#  0.0022447858937084675,
#  0.0019568689167499542,
#  0.0019181219395250082,
#  0.002435141010209918,
#  0.0016693039797246456,
#  0.001657168148085475,
#  0.001395639730617404,
#  0.00166505784727633,
#  0.001667332835495472,
#  0.0020010476000607014,
#  0.0011141656432300806,
#  0.001866068341769278,
#  0.0011823495151475072,
#  0.0016000830801203847,
#  0.0017021055100485682,
#  0.0013905537780374289,
#  0.0012613859726116061,
#  0.0014680472668260336,
#  0.0011315059382468462,
#  0.0014602004084736109,
#  0.001054897322319448,
#  0.001429682015441358,
#  0.0010196762159466743,
#  0.0011184446047991514,
#  0.0014736650045961142,
#  0.0008929695468395948,
#  0.0011442244285717607,
#  0.0013278118567541242,
#  0.0007836343720555305,
#  0.0014044629642739892,
#  0.0009306252468377352,
#  0.0012901973677799106,
#  0.0010801720200106502,
#  0.0012529781088232994,
#  0.000846075068693608,
#  0.0011390744475647807,
#  0.001136118546128273,
#  0.0009064423502422869,
#  0.0009230032446794212,
#  0.001093999482691288,
#  0.0011401172960177064,
#  0.000801694521214813,
#  0.000721603340934962,
#  0.0010246668243780732,
#  0.0009896043920889497,
#  0.0008386573754251003,
#  0.0009702502284198999,
#  0.0008353705052286386,
#  0.0007685438613407314]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'mape', 'val_loss', 'val_mae', 'val_mape'])

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["mape"])
plt.plot(history.history["val_mape"])
plt.xlabel("Epochs")
plt.ylabel("mape")
plt.title("Simple RNN model, Accuracy vs. Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data¶

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred.shape
# Out:
# (311, 1)

# %%
pd.DataFrame(y_pred).pct_change().plot()
pd.DataFrame(y_train).pct_change().plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame({"y_pred":y_pred.flatten(), "y_true":y_train.flatten()}).plot()
# Out:
# <AxesSubplot:>

# %%
#y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (311, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("ratio")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating Test Dataset from Validation Data

# %%
#Converting array and scaling
dataset_validation = validation_data.ALB_ZBRA.values  # getting "Ratio" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
#scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling  values to between 0 and 1
scaled_dataset_validation = dataset_validation 

print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (149, 1)

# %%
#Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (129, 20)
# Shape of y_test before reshape : (129,)

# %%
#reshape
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (129, 20, 1)
# Shape of y_test after reshape : (129, 1)

# %% [markdown]
# ## Evaluating with Validation Data

# %%
regressor.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0039 - mae: 0.0553 - mape: 8.3913
# [0.003918002359569073, 0.0553431510925293, 8.391302108764648]

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
#y_pred_of_test = scaler.inverse_transform(y_pred_of_test) 
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# Shape of y_pred_of_test : (129, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(y_test, label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Ratio")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.ALB_ZBRA, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.ALB_ZBRA, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("ratio")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gr/22150sz94ggcqgt36_pzrbrw0000gn/T/ipykernel_97332/497942232.py in <module>
#       3 plt.plot(train_data.Date, train_data.ALB_ZBRA, label = "train_data", color = "b")
#       4 plt.plot(validation_data.Date, validation_data.ALB_ZBRA, label = "validation_data", color = "g")
# ----> 5 plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
#       6 plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
#       7 plt.xlabel("Days")
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (328,) and (311, 1)

# %% [markdown]
# ## Future price prediction

# %%
#last day in our data?
df.iloc[-1]
# Out:
# Date        2022-08-19
# ALB_ZBRA      0.822204
# NRG_CPRT      0.334919
# DE_BXP         4.28095
# NRG_STE       0.204631
# NRG_XRAY      1.200391
# SO_NLOK       3.405268
# PEG_O         0.951858
# Name: 496, dtype: object

# %% [markdown]
# ### We can predict the ratio for the day after 2022-08-23--> for 2022-08-24.
# We will use last ratios as input of our model for this prediction.

# %%
X_input = df.iloc[-time_step:].ALB_ZBRA.values             # getting last rows and converting to array
X_input = X_input.reshape(-1,1)     # converting to 2D array and scaling
X_input = np.reshape(X_input, (1,time_step,1))                    # reshaping: converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 20, 1)
# array([[[0.69941916],
#         [0.68844238],
#         [0.69216225],
#         [0.6859797 ],
#         [0.6830216 ],
#         [0.66947524],
#         [0.75433006],
#         [0.73386229],
#         [0.71053908],
#         [0.71748567],
#         [0.74122061],
#         [0.76420431],
#         [0.78845742],
#         [0.79077385],
#         [0.81204942],
#         [0.81302763],
#         [0.8141544 ],
#         [0.8154501 ],
#         [0.81637364],
#         [0.82220391]]])

# %%
simple_RNN_prediction = regressor.predict(X_input)
print("Simple RNN, prediction for 2022-08-24:", simple_RNN_prediction[0,0])
# Out:
# Simple RNN, prediction for 2022-08-24: 0.728494
