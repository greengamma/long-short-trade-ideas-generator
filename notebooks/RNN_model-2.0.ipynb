# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import data
df = pd.read_csv(r'cleaned_data.csv')
df.head()
# Out:
#          Date   TEL_BIO   ADP_SYK     ON_MU  ROST_VFC      CDW_T  PAYX_RTX  \
# 0  2022-02-23  0.239509  0.771140  0.663637  1.560298   9.729875  1.237427
# 1  2022-02-24  0.234301  0.774126  0.689893  1.592246  10.004847  1.227451
# 2  2022-02-25  0.223696  0.766083  0.707117  1.601182  10.073827  1.208059
# 3  2022-02-28  0.225564  0.773484  0.706936  1.594907   9.877013  1.158270
# 4  2022-03-01  0.217456  0.767553  0.693815  1.633461   9.768311  1.143246
#
#     APH_STE  NDSN_STE   CAH_NEM   CEG_NEM   DIS_NEM    IT_NEM   NRG_NEM  \
# 0  0.326856  0.983616  0.781127  0.636250  2.170135  4.069952  0.537846
# 1  0.326426  0.963968  0.784539  0.671616  2.273621  4.282290  0.570192
# 2  0.322575  0.955513  0.796171  0.653839  2.236053  4.284883  0.557495
# 3  0.315486  0.940690  0.813754  0.702244  2.277063  4.301050  0.569553
# 4  0.311195  0.937899  0.763564  0.700168  2.143734  4.038225  0.527591
#
#    SCHW_NEM    TT_NEM
# 0  1.220489  2.195844
# 1  1.244242  2.280275
# ...

# %%
df.tail(2)
# Out:
#            Date   TEL_BIO   ADP_SYK     ON_MU  ROST_VFC      CDW_T  PAYX_RTX  \
# 124  2022-08-22  0.259488  1.207346  1.179901  2.042420  10.210149  1.481151
# 125  2022-08-23  0.262075  1.223818  1.219254  2.019504  10.250831  1.469649
#
#       APH_STE  NDSN_STE   CAH_NEM   CEG_NEM   DIS_NEM    IT_NEM   NRG_NEM  \
# 124  0.376850  1.135514  1.549749  1.817663  2.645824  6.927659  0.960748
# 125  0.382309  1.179573  1.535980  1.800135  2.600045  6.834310  0.946443
#
#      SCHW_NEM    TT_NEM
# 124  1.655637  3.642857
# 125  1.646064  3.557072

# %%
df.shape
# Out:
# (126, 16)

# %%
# we check TEL_BIO first
df_tel_bio=df[["Date","TEL_BIO"]]
df_tel_bio.head()
# Out:
#          Date   TEL_BIO
# 0  2022-02-23  0.239509
# 1  2022-02-24  0.234301
# 2  2022-02-25  0.223696
# 3  2022-02-28  0.225564
# 4  2022-03-01  0.217456

# %%
df_tel_bio.shape
# Out:
# (126, 2)

# %%
df_tel_bio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     126 non-null    object
#  1   TEL_BIO  126 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## Spliting Data in Train and Validation

# %%
length_data = len(df_tel_bio)     # rows that data has
split_ratio = 0.7           # %70 train + %30 validation
length_train = round(length_data * split_ratio)  
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length:", length_train)
print("Validation data lenth:", length_validation)
# Out:
# Data length : 126
# Train data length: 88
# Validation data lenth: 38

# %%
# train_data
train_data = df_tel_bio[:length_train].iloc[:,:2] 
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#          Date   TEL_BIO
# 0  2022-02-23  0.239509
# 1  2022-02-24  0.234301
# 2  2022-02-25  0.223696
# 3  2022-02-28  0.225564
# 4  2022-03-01  0.217456
# ..        ...       ...
# 83 2022-06-23  0.227687
# 84 2022-06-24  0.232164
# 85 2022-06-27  0.230585
# 86 2022-06-28  0.231131
# 87 2022-06-29  0.226631
#
# [88 rows x 2 columns]

# %%
# validation_data
validation_data = df_tel_bio[length_train:].iloc[:,:2]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#           Date   TEL_BIO
# 88  2022-06-30  0.227644
# 89  2022-07-01  0.220056
# 90  2022-07-05  0.219389
# 91  2022-07-06  0.220271
# 92  2022-07-07  0.223118
# 93  2022-07-08  0.221547
# 94  2022-07-11  0.215217
# 95  2022-07-12  0.224959
# 96  2022-07-13  0.226481
# 97  2022-07-14  0.229444
# 98  2022-07-15  0.233146
# 99  2022-07-18  0.240854
# 100 2022-07-19  0.243865
# 101 2022-07-20  0.245357
# 102 2022-07-21  0.232604
# 103 2022-07-22  0.233585
# 104 2022-07-25  0.232029
# 105 2022-07-26  0.229190
# 106 2022-07-27  0.232862
# 107 2022-07-28  0.233432
# 108 2022-07-29  0.236444
# 109 2022-08-01  0.237651
# 110 2022-08-02  0.238793
# 111 2022-08-03  0.241876
# 112 2022-08-04  0.246290
# 113 2022-08-05  0.245699
# 114 2022-08-08  0.247388
# 115 2022-08-09  0.251513
# 116 2022-08-10  0.243682
# 117 2022-08-11  0.243493
# 118 2022-08-12  0.249197
# 119 2022-08-15  0.249973
# 120 2022-08-16  0.256351
# 121 2022-08-17  0.258362
# 122 2022-08-18  0.263737
# 123 2022-08-19  0.264347
# ...

# %% [markdown]
# ## Creating Train Dataset from Train split

# %%
dataset_train = train_data.TEL_BIO.values
dataset_train.shape
# Out:
# (88,)

# %%
# Change 1d array to 2d array
# Changing shape from (1692,) to (1692,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (88, 1)

# %% [markdown]
# ## Normalization / Feature Scaling

# %%
# Dataset values will be in between 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (88, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days 1st, 2nd, 3rd..")
plt.ylabel("Ratio")
plt.show()

# %% [markdown]
# ## Creating X_train and y_train from Train data

# %% [markdown]
# We have train data composed of ratios over days
#
# So, it has 1184 ratios corresponding 1184 days
#
# My aim is to predict the ratio (closing) of the next day.
#
# I can use a time step of 2 days.
#
# I will pick first 2 ratios (day 0 to 2), 1st 2 ratio will be in
# X_train data
#
# Then predict the ratio of 3rd day; and 3rd ratio will be in y_train data
#
# Again, i will pick ratios from 1 to 3, those will be in X_train data
#
# Then predict the next days ratio, 4th ratio will be in y_train data

# %%
X_train = []
y_train = []

time_step = 3 #days

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])
    
# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (85, 3)
# Shape of y_train before reshape : (85,)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (85, 3, 1)
# Shape of y_train after reshape : (85, 1)

# %% [markdown]
# Shape of X_train : 1134 x 50 x 1
# That means we have 1134 rows, each row has 50 rows and 1 column
# Lets check the first row: it has 50 rows (ratio of 49 days)

# %%
X_train[0]
# Out:
# array([[0.67470518],
#        [0.5662432 ],
#        [0.34541468]])

# %% [markdown]
# Check the first item in y_train
# It is the ratio of 2nd day

# %%
y_train[0]
# Out:
# array([0.38430519])

# %% [markdown]
# ## Creating RNN model

# %% [markdown]
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import SimpleRNN
# from keras.layers import Dropout
#
# # initializing the RNN
# regressor = Sequential()
#
# #adding layers
# regressor.add(layers.SimpleRNN(units=2, activation='tanh', input_shape=(4,3)))
# regressor.add(layers.Dense(1, activation="linear"))
#
# # The compilation
# regressor.compile(loss='mse', optimizer='rmsprop')  # Recommended optimizer for RNNs
#
# # The fit
# regressor.fit(X, y, batch_size=16,epochs=10, verbose=0)
#
# # The prediction (one per sequence/city)
# regressor.predict(X)

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True, input_shape = (X_train.shape[1],1)))
regressor.add(Dropout(0.2)) #check that

# adding second RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50, activation = "tanh", return_sequences = True))
regressor.add(Dropout(0.2)) #check that

# adding third RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50, activation = "tanh",return_sequences = True))
regressor.add(Dropout(0.2)) #check that

# adding fourth RNN layer and dropout regulatization
regressor.add(SimpleRNN(units = 50, activation='linear'))
regressor.add(Dropout(0.2)) #check that

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(optimizer = "rmsprop",loss = "mean_squared_error",metrics = ["accuracy", "mae"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 50, batch_size = 64)
# Out:
# 2022-08-29 18:39:29.130160: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-29 18:39:29.369067: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2/2 [==============================] - 15s 4ms/step - loss: 1.3642 - accuracy: 0.0209 - mae: 0.8722
# Epoch 2/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5805 - accuracy: 0.0131 - mae: 0.6003
# Epoch 3/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.0157 - mae: 0.4796
# Epoch 4/50
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5065 - accuracy: 0.0261 - mae: 0.5734
# Epoch 5/50
# ...

# %% [markdown]
# ## Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [1.7121998071670532,
#  0.5668928623199463,
#  0.4361076354980469,
#  0.4921307861804962,
#  0.3735477328300476,
#  0.33944234251976013,
#  0.33826544880867004,
#  0.31482645869255066,
#  0.250007301568985,
#  0.3419659435749054,
#  0.16472643613815308,
#  0.2885333299636841,
#  0.2528822422027588,
#  0.19850026071071625,
#  0.1854812204837799,
#  0.15360769629478455,
#  0.1775471568107605,
#  0.1659119725227356,
#  0.12479602545499802,
#  0.15917743742465973,
#  0.14504635334014893,
#  0.11788097769021988,
#  0.12114269286394119,
#  0.11116459965705872,
#  0.10065343230962753,
#  0.1265486478805542,
#  0.08512028306722641,
#  0.09926839917898178,
#  0.08625851571559906,
#  0.08296012133359909,
#  0.10319577157497406,
#  0.1409032642841339,
#  0.10276002436876297,
#  0.10900517553091049,
#  0.07264567911624908,
#  0.09660031646490097,
#  0.10147098451852798,
#  0.06914468854665756,
#  0.077053964138031,
#  0.0766499787569046,
#  0.0664752870798111,
#  0.08955476433038712,
# ...

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data¶

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred = scaler.inverse_transform(y_pred) # scaling back from 0-1 to original
y_pred.shape
# Out:
# (85, 1)

# %%
y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (85, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("ratio")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating Test Dataset from Validation Data

# %%
#Converting array and scaling
dataset_validation = validation_data.TEL_BIO.values  # getting "Ratio" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling  values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (38, 1)

# %%
#Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (35, 3)
# Shape of y_test before reshape : (35,)

# %%
#reshape
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (35, 3, 1)
# Shape of y_test after reshape : (35, 1)

# %% [markdown]
# ## Evaluating with Validation Data

# %%
regressor.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 1s 2ms/step - loss: 0.0184 - accuracy: 0.0571 - mae: 0.1165
# [0.01838122308254242, 0.05714285746216774, 0.11653289943933487]

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test) 
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# Shape of y_pred_of_test : (35, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Ratio")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.TEL_BIO, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.TEL_BIO, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("ratio")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()

# %% [markdown]
# ## Creating LSTM Model

# %%
y_train = scaler.fit_transform(y_train)

# %%
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy"])
history2 = model_lstm.fit(X_train, y_train, epochs = 10, batch_size = 10)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 3s 4ms/step - loss: 0.2612 - accuracy: 0.0036
# Epoch 2/10
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.0086
# Epoch 3/10
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.0231
# Epoch 4/10
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.0086
# Epoch 5/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.0162
# Epoch 6/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.0117
# Epoch 7/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.0291
# Epoch 8/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.0136
# Epoch 9/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.0162
# Epoch 10/10
# ...

# %% [markdown]
# ## Evaluating LSTM Model

# %%
model_lstm.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.0571
# [0.014862535521388054, 0.05714285746216774]

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Accuracy vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_lstm.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Ratio")
plt.title("LSTM model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()

# %% [markdown]
# ## New model

# %%
y_train = scaler.fit_transform(y_train)

# %%
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU


model_new = Sequential()
model_new.add(
    LSTM(64,return_sequences=True,input_shape = (X_train.shape[1],1))) #64 lstm neuron block
model_new.add(LSTM(64, return_sequences= False))
model_new.add(Dense(32))
model_new.add(Dense(1))
model_new.compile(loss = "mean_squared_error", optimizer = "rmsprop", metrics = ["accuracy"])

history3 = model_new.fit(X_train, y_train, epochs = 10, batch_size = 10)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 6s 4ms/step - loss: 0.2888 - accuracy: 0.0050
# Epoch 2/10
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 0.0154
# Epoch 3/10
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.0291
# Epoch 4/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.0072
# Epoch 5/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.0382
# Epoch 6/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.0101
# Epoch 7/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.0137
# Epoch 8/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.0407
# Epoch 9/10
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0137
# Epoch 10/10
# ...

# %% [markdown]
# ## Evaluation new model

# %%
model_new.evaluate(X_test, y_test)

# %%
plt.figure(figsize =(10,5))
plt.plot(history2.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("LSTM model, Accuracy vs Epoch")
plt.show()

# %%
plt.subplots(figsize =(30,12))
plt.plot(scaler.inverse_transform(model_new.predict(X_test)), label = "y_pred_of_test", c = "orange" )
plt.plot(scaler.inverse_transform(y_test), label = "y_test", color = "g")
plt.xlabel("Days")
plt.ylabel("Ratio")
plt.title("new model, Predictions with input X_test vs y_test")
plt.legend()
plt.show()

# %% [markdown]
# ## Future price prediction

# %%
#last day in our data?
df_tel_bio.iloc[-1]
# Out:
# Date       2022-08-23
# TEL_BIO      0.262075
# Name: 125, dtype: object

# %% [markdown]
# ### We can predict the ratio for the day after 2022-08-23--> for 2022-08-24.
# We will use last ratios as input of our model for this prediction.

# %%
X_input = df.iloc[-time_step:].TEL_BIO.values             # getting last rows and converting to array
X_input = scaler.fit_transform(X_input.reshape(-1,1))     # converting to 2D array and scaling #add time_step in middle
X_input = np.reshape(X_input, (1,time_step,1))                    # reshaping: converting to 3D array
print("Shape of X_input :", X_input.shape)
X_input
# Out:
# Shape of X_input : (1, 3, 1)
# array([[[1.        ],
#         [0.        ],
#         [0.53227049]]])

# %%
simple_RNN_prediction = scaler.inverse_transform(regressor.predict(X_input))
LSTM_prediction = scaler.inverse_transform(model_lstm.predict(X_input))
model_new_prediction = scaler.inverse_transform(model_new.predict(X_input))


print("Simple RNN, prediction for 2022-08-24:", simple_RNN_prediction[0,0])
print("LSTM, prediction for 2022-08-24:", LSTM_prediction[0,0])
print("New Model, prediction for 2022-08-24:", model_new_prediction[0,0])
# Out:
# Simple RNN, prediction for 2022-08-24: 0.2623413
# LSTM, prediction for 2022-08-24: 0.26224446
